# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
img = cv2.imread('./images/cameraman.tif', 0)

# %%
plt.axis('off')
plt.imshow(img, cmap='gray')
plt.show()

# %%
gy = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]], dtype='float16')
print(gy)
# Out:
# [[-1.  0.  1.]
#  [-1.  0.  1.]
#  [-1.  0.  1.]]

# %%
gx = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]], dtype='float16')
print(gx)
# Out:
# [[-1. -1. -1.]
#  [ 0.  0.  0.]
#  [ 1.  1.  1.]]

# %%
f = img.copy().astype(np.float16)

# %%
outC = np.zeros_like(img, dtype='float16')
outR = np.zeros_like(img, dtype='float16')

# %%
m, n = img.shape
print(m, n)
# Out:
# 512 512

# %%
for i in range(1,m-1):
    for j in range(1,n-1):
        tmp = 0
        for p in range(3):
            for q in range(3):
                tmp = tmp + (gy[p,q]*f[i+p-1,j+q-1])
        outC[i,j] = abs(tmp)

# %%
for i in range(1,m-1):
    for j in range(1,n-1):
        tmp = 0
        for p in range(3):
            for q in range(3):
                tmp = tmp + (gx[p,q]*f[i+p-1,j+q-1])
        outR[i,j] = abs(tmp) 
        out[i, j] = math.sqrt(pow )

# %%
outC = outC.astype(np.uint8)
outR = outR.astype(np.uint8)

# %%
mul = cv2.hconcat([outC, outR])
plt.axis('off')
plt.imshow(mul, cmap='gray')
plt.show()
