# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("./images/Noisy-Lena-image-The-noise-is-AWGN-with-standard-deviation-35.png", 0)

# %%
print(type(img), img.shape)
# Out:
# <class 'numpy.ndarray'> (254, 254)

# %%
plt.axis("off")
plt.imshow(img, cmap='gray')
plt.show()

# %%
k = 3
# mask = np.ones([k, k], dtype ='float16')
mask = np.array([[1, 2, 1], [2, 4, 2], [1, 2, 1]], dtype='float16')
# mask = mask/pow(k, 2)
mask = mask/16
print(mask)
# Out:
# [[0.0625 0.125  0.0625]
#  [0.125  0.25   0.125 ]
#  [0.0625 0.125  0.0625]]

# %%
b= int(k/2)
print(k)
# Out:
# 3

# %%
f = img.copy().astype(np.float16)

# %%
out = np.zeros_like(img)

# %%
m, n = img.shape
print(m, n)
# Out:
# 254 254

# %%
for i in range(b, m-b) :
    for j in range(b, n-b) :
        tmp = 0
        for p in range(k) :
            for q in range(k) :
                tmp = tmp + (mask[p, q] * f[i+p-b, j+q-b])
        out[i,j] = tmp

# %%
for i in range(b, m-b) :
    for j in range(b, n-b) :
        sub_i = i[i-bd :bd+1]

# %%
out = out.astype(np.uint8)

# %%
imgs = cv2.hconcat([img, out])

# %%
plt.axis("off")
plt.imshow(imgs, cmap='gray')
plt.show()
